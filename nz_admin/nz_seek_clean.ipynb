# %%
import csv

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

LOCATION_INDEX = {'admin':3,'banking':3,'ceo':3}
POSTTIME_INDEX = {'admin':4,'banking':5,'ceo':5}
CLASSIFIACTION_INDEX = {'admin':5,'banking':4,'ceo':4}
SALARY_INDEX = {'admin':5,'banking':6,'ceo':3}

LOCATION_LENGTH = 9
CLASSIFIACTION_LENGTH = 15

# %%
def deduplication(x):
    if not x:
        return 'unkown'
    trim = x.strip()
    index = (trim+trim).find(trim,1)
    if index != -1:
        return trim[:index]
    else:
        return 'unknown'
def apply_classification(x):
    if 'classification' in x:
        return x[CLASSIFIACTION_LENGTH:]
    else:
        return 'unknown'
def apply_salary(x):
    if 'classification:' in x:
        return 'unknown'
    else:
        return x
def apply_posted_time(x):
    if 'd' in x:
        return -int(x[:-1])
    if 'm' in x:
        return -(int(x[:-1])*30)
    else:
        return 0
def anually_salary(x):
    if x != 'unknown' and float(x) < 100:
        return float(x) * 8 * 200
    else:
        return x

# %%
def clean_location(df,data):
    df[LOCATION_INDEX[data]] = df[LOCATION_INDEX[data]].str.split(',', expand=True)[0]
    df[['location','area']] = df[LOCATION_INDEX[data]].str.split('area:',expand = True)
    df['location'] = df['location'].apply(lambda x:x[LOCATION_LENGTH:])
    df['location'] = df['location'].apply(deduplication)
    df['area'] = df['area'].apply(deduplication)
    df.drop(LOCATION_INDEX[data], axis = 1, inplace = True)
    return df

# %%
def clean_classification(df,data):
    df[['classification','subclassification']] = df[CLASSIFIACTION_INDEX[data]].str.split('subClassification:',expand = True)
    df['classification'] = df['classification'].apply(apply_classification)
    df['subclassification'] = df['subclassification'].apply(deduplication)
 
    df['salary'] = df[SALARY_INDEX[data]].apply(apply_salary)
    df.drop([CLASSIFIACTION_INDEX[data]],axis = 1, inplace = True)
    return df

# %%
def clean_posttime(df,data):
    df.rename(columns ={0:'Job title',1:'url',2:'company'}, inplace = True )
    df[['posted time','featured']] = df[POSTTIME_INDEX[data]].str.split(',', expand = True)[[0,2]]
    df['featured'].fillna('unknown',inplace = True)
    df.drop([POSTTIME_INDEX[data]],axis = 1, inplace = True)
    df['posted time']=df['posted time'].str.extract('(\d+[a-z])')
    df['posted time'].fillna('unknown', inplace = True)
    df['posted time']=df['posted time'].apply(apply_posted_time)
    df['company'].fillna(df['featured'], inplace = True)
    return df

# %%
def clean_salary(df):
    df['salary']=df[df['salary'].str.contains('\d', na=False)]['salary'].str.replace(' to ','-',regex=True)
    df['salary']=df[df['salary'].str.contains('\d', na=False)]['salary'].str.replace('\d\%','',regex=True)
    df['salary']=df[df['salary'].str.contains('\d', na=False)]['salary'].str.replace(',','',regex=True)
    df['salary'].fillna('unknown')
    df[['low salary','high salary']] = df['salary'].str.split('-', n=1, expand = True).fillna('unknown')
    df['low salary'] = df['low salary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')
    df['high salary'] = df['high salary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')
    df['low salary'] = df[df['low salary'].str.contains('\d', na=False)]['low salary'].str.replace('k', '000', regex=True)
    df['high salary'] = df[df['high salary'].str.contains('\d', na=False)]['high salary'].str.replace('k', '000', regex=True)
    df['low salary'] = df[df['low salary'].str.contains('\d', na=False)]['low salary'].str.replace(' ', '', regex=True)
    df['high salary'] = df[df['high salary'].str.contains('\d', na=False)]['high salary'].str.replace(' ', '', regex=True)
    df['low salary']=df['low salary'].fillna("unknown")
    df['high salary']=df['high salary'].fillna("unknown")
    df.loc[df['low salary'] == 'unknown', 'low salary'] = df['high salary']
    df.loc[df['high salary'] == 'unknown', 'high salary'] = df['low salary']
    df['low salary'] = df['low salary'].apply(anually_salary)
    df['high salary'] = df['high salary'].apply(anually_salary)
    df.drop('salary',axis = 1, inplace = True)
    return df

# %%
def clean_seek(df,data):
    
    df = clean_location(df,data)
    df = clean_classification(df,data)
    df = clean_posttime(df,data)
    df = clean_salary(df)
    return df

# %%
df_admin = pd.read_csv ('NZ_Admin_JOBS.xlsx - sheet1.csv',header = None)
df_admin = df_admin.drop(0)
df_admin = clean_seek(df_admin,'admin')
df_admin
# Out:
#                                  Job title  \
# 1                            Administrator
# 2                             Receptionist
# 3             Prosecutions Support Officer
# 4     Early Childhood Centre Administrator
# 5           Business Support Administrator
# ...                                    ...
# 2704                   Key Account Manager
# 2705                   Executive Assistant
# 2706                Temporary Office Roles
# 2707                Temporary Office Roles
# 2708                   Executive Assistant
#
#                                                     url  \
# 1     https://www.seek.co.nz/job/50582301?type=promo...
# 2     https://www.seek.co.nz/job/50620889?type=promo...
# 3     https://www.seek.co.nz/job/50622169?type=stand...
# 4     https://www.seek.co.nz/job/50639620?type=stand...
# 5     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2704  https://www.seek.co.nz/job/50490062?type=stand...
# 2705  https://www.seek.co.nz/job/50488000?type=stand...
# 2706  https://www.seek.co.nz/job/50524865?type=stand...
# 2707  https://www.seek.co.nz/job/50477118?type=stand...
# 2708  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                        company       location  \
# 1                           Private Advertiser  Bay of Plenty
# 2                         Avenues Orthodontics  Bay of Plenty
# 3                           New Zealand Police       Auckland
# 4     Kew Pacific Island Early Learning Centre      Southland
# 5                           Private Advertiser     Canterbury
# ...                                        ...            ...
# 2704                     Hays Talent Solutions       Auckland
# 2705                    one eighty recruitment     Wellington
# 2706                     Asset Recruitment Ltd        Waikato
# 2707                     Asset Recruitment Ltd        Waikato
# 2708                    Alpha Recruitment - NZ     Wellington
#
#                     area                                     classification  \
# 1               Tauranga   Administration & Office SupportAdministration...
# 2               Tauranga   Administration & Office SupportAdministration...
# 3                 unkown   Administration & Office SupportAdministration...
# 4           Invercargill   Administration & Office SupportAdministration...
# 5           Christchurch   Administration & Office SupportAdministration...
# ...                  ...                                                ...
# 2704    Auckland Central   Administration & Office SupportAdministration...
# 2705  Wellington Central                                            unknown
# 2706            Hamilton                                            unknown
# 2707            Hamilton                                            unknown
# 2708              unkown   Administration & Office SupportAdministration...
#
#                   subclassification  posted time            featured  \
# 1                 Office Management            0  Private Advertiser
# 2                     Receptionists            0             unknown
# 3                             Other           -4             unknown
# 4         Administrative Assistants            0             unknown
# 5     Client & Sales Administration           -4  Private Advertiser
# ...                             ...          ...                 ...
# 2704  Client & Sales Administration          -27             unknown
# 2705                         unkown          -27             unknown
# 2706                         unkown          -20             unknown
# 2707                         unkown          -28             unknown
# 2708           PA, EA & Secretarial          -26             unknown
#
#      low salary high salary
# 1       unknown     unknown
# 2       unknown     unknown
# 3       unknown     unknown
# 4       unknown     unknown
# 5       unknown     unknown
# ...         ...         ...
# 2704    unknown     unknown
# 2705    unknown     unknown
# 2706    unknown     unknown
# 2707    unknown     unknown
# 2708    unknown     unknown
#
# [2708 rows x 11 columns]

# %%
df_banking = pd.read_excel(r"NZ_Banking_JOBS.xlsx", header = None)
df_banking = df_banking.drop(0)
df_banking = clean_seek(df_banking,'banking')
df_banking.drop(6,axis = 1, inplace = True)
df_banking
# Out:
#                                               Job title  \
# 1                                   Accounts Receivable
# 2                                Internal Audit Manager
# 3                               Client Services Officer
# 4            Customer Banking Consultant - Invercargill
# 5                 Private Wealth Assistant - Queenstown
# ...                                                 ...
# 3880                                  Financial Advisor
# 3881                   Senior Private Wealth Specialist
# 3882                       Financial Adviser (Auckland)
# 3883                               New Ventures Manager
# 3884  Regulatory and Compliance Manager-12 month con...
#
#                                                     url  \
# 1     https://www.seek.co.nz/job/50568753?type=promo...
# 2     https://www.seek.co.nz/job/50556333?type=promo...
# 3     https://www.seek.co.nz/job/50638706?type=stand...
# 4     https://www.seek.co.nz/job/50637958?type=stand...
# 5     https://www.seek.co.nz/job/50617226?type=stand...
# ...                                                 ...
# 3880  https://www.seek.co.nz/job/50497173?type=stand...
# 3881  https://www.seek.co.nz/job/50526368?type=stand...
# 3882  https://www.seek.co.nz/job/50501103?type=stand...
# 3883  https://www.seek.co.nz/job/50487878?type=stand...
# 3884  https://www.seek.co.nz/job/50575511?type=stand...
#
#                                                 company   location  \
# 1                          at MTF Finance Mt Wellington   Auckland
# 2     at Industrial and Commercial Bank of China (Ne...   Auckland
# 3                        at NZ Funds Management Limited   Auckland
# 4                                            at Westpac  Southland
# 5                         at Craigs Investment Partners      Otago
# ...                                                 ...        ...
# 3880                                      at NetYourJob   Auckland
# 3881              at Debbie Graham & Associates Limited   Auckland
# 3882                                      at Tyler Wren   Auckland
# 3883                             at Matthew Wood Search   Auckland
# 3884              at Debbie Graham & Associates Limited   Auckland
#
#                       area                                     classification  \
# 1         Auckland Central   Banking & Financial ServicesBanking & Financi...
# 2         Auckland Central   Banking & Financial ServicesBanking & Financi...
# 3         Auckland Central   Banking & Financial ServicesBanking & Financi...
# 4             Invercargill   Banking & Financial ServicesBanking & Financi...
# 5      Queenstown & Wanaka   Banking & Financial ServicesBanking & Financi...
# ...                    ...                                                ...
# 3880  Rodney & North Shore   Banking & Financial ServicesBanking & Financi...
# 3881                unkown   Banking & Financial ServicesBanking & Financi...
# 3882      Auckland Central   Banking & Financial ServicesBanking & Financi...
# 3883      Auckland Central   Banking & Financial ServicesBanking & Financi...
# 3884      Auckland Central   Banking & Financial ServicesBanking & Financi...
#
#                            subclassification  posted time featured low salary  \
# 1                                     Credit            0  unknown    unknown
# 2                          Compliance & Risk            0  unknown    unknown
# 3                            Client Services            0  unknown    unknown
# 4                    Banking - Retail/Branch           -1  unknown    unknown
# 5                            Client Services           -5  unknown    unknown
# ...                                      ...          ...      ...        ...
# 3880                      Financial Planning          -26  unknown    unknown
# 3881                      Financial Planning          -20  unknown    unknown
# 3882                      Financial Planning          -25  unknown    unknown
# 3883  Corporate Finance & Investment Banking          -27  unknown    unknown
# 3884                       Compliance & Risk          -12  unknown    unknown
#
#      high salary
# 1        unknown
# 2        unknown
# 3        unknown
# 4        unknown
# 5        unknown
# ...          ...
# 3880     unknown
# 3881     unknown
# 3882     unknown
# 3883     unknown
# 3884     unknown
#
# [3884 rows x 11 columns]
